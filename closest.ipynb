# %% [markdown]
# Looking at the giant neaby star

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.modeling import models, fitting
import lightkurve as lk
from astropy.timeseries import LombScargle
import scipy.signal as signal

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
from lightkurve import search_targetpixelfile
pixelfile = search_targetpixelfile('GD394', sector=15).download(quality_bitmask='hardest')

# %%
pixelfile.plot(frame=1,aperture_mask=pixelfile.pipeline_mask);

# %%
pixelfile.interact()
# Out:
# <script src="http://localhost:43721/autoload.js?bokeh-autoload-element=6364&bokeh-absolute-url=http://localhost:43721&resources=none" id="6364"></script>
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: RangeSlider(id='6463', ...)

# %%
lc = lk.lightcurvefile.LightCurveFile(path='tess2019226182529-s0015-0000000259773610-0151-s_tp-custom-lc.fits') 
lc1 = fits.open('tess2019226182529-s0015-0000000259773610-0151-s_tp-custom-lc.fits')
data = lc1[1].data
lc2 = lk.LightCurve(time=data['TIME'], flux= data['FLUX'])
#lc2.scatter()

pg = lc2.to_periodogram(oversample_factor=10,minimum_period=0.8*u.day, maximum_period=1.5*u.day)
#plt.plot(pg.period, pg.power)

pg.plot()
print(pg.period_at_max_power)
# Out:
# 1.0109293599047895 d

# %%
pf16 = search_targetpixelfile('GD394', sector=16).download(quality_bitmask='hardest')

# %%
pf16.plot(frame=1,aperture_mask=pixelfile.pipeline_mask);

# %%
pf16.interact()
# Out:
# <script src="http://localhost:37449/autoload.js?bokeh-autoload-element=4640&bokeh-absolute-url=http://localhost:37449&resources=none" id="4640"></script>
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: RangeSlider(id='4739', ...)

# %%
lc12 = fits.open('tess2019253231442-s0016-0000000259773610-0152-s_tp-custom-lc.fits')
data = lc12[1].data
lc22 = lk.LightCurve(time=data['TIME'], flux= data['FLUX'])
#lc2.scatter()

pg2 = lc22.to_periodogram(oversample_factor=10,minimum_period=0.8*u.day, maximum_period=1.2*u.day)
plt.plot(pg2.period, pg2.power)

# %%
pixelfile.interact_sky()
# Out:
# <script src="http://localhost:44869/autoload.js?bokeh-autoload-element=5048&bokeh-absolute-url=http://localhost:44869&resources=none" id="5048"></script>
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: RangeSlider(id='5090', ...)
