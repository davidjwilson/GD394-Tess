# %% [markdown]
# Looking at the giant neaby star

# %%
from lightkurve import search_targetpixelfile
pixelfile = search_targetpixelfile('GD394', sector=15).download(quality_bitmask='hardest')

# %%
pixelfile.plot(frame=1);

# %%
pixelfile.interact()
# Out:
#   File "<ipython-input-7-5b3c718cbc68>", line 1
#     --allow-websocket-origin=localhost:8889 or set BOKEH_ALLOW_WS_ORIGIN=localhost:8889
#                                       ^
# SyntaxError: invalid syntax
